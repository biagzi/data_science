# %% [markdown]
# good for image classification, by doing a convolution using "atomic elements", then sub-motifs and then complex motifs when increasing the layers of complexity ("filters").

# %%
from IPython.display import Image
Image("CNN.png",width = 200, height = 100)
#The G is the classifiet and can be Logistic Regression or Multilayer Percepton, for example

# %% [markdown]
# the hierarchical layers structures ensure that the more complex motifs share knowledge about the simpler motifs, what improves the understanding (prediction) of the model of the basic parts and structures of the data.
