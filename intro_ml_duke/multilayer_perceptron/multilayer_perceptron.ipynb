# %% [markdown]
# Generalization of Logistic Regression: Do K times the LR procedure
#
# Logistic regression takes a single filter, this way we have a series of K filters (latent processes) that correspond to K different ways of the classification solution

# %%
from IPython.display import Image
Image("generalization_LR.png",width = 200, height = 100)

# %% [markdown]
# It allow to consider non linear decision boundaries in the vector space

# %% [markdown]
# Multilayer perceptron is a kind of deep learn.
#
# Example for interpretation:

# %%
Image("example_for_interpretation.png",width = 200, height = 100)
