# %%
import pandas as pd

# %%
df_raw= pd.read_csv('raw_data/test_raw_data.csv')

# %%
df_raw.head()
# Out:
#               CPF  Potencial Bruto  Raciocínio  Social  Motivacional  \
# 0  582.975.481-98            15.02       10.89    8.50         30.78
# 1  618.492.035-98            41.18       27.31   31.07         77.53
# 2  376.104.598-11            56.78       71.39   47.53         46.36
# 3  056.378.194-75              NaN       63.01     NaN           NaN
# 4  235.406.789-56            50.96       79.87   21.19         46.36
#
#    Cultura pontuação Cultura classificação  atributo-Capacidade analítica  \
# 0              61.62            Médio-alto                           9.02
# 1              71.92                  Alto                          15.53
# 2              49.10                 Médio                          81.20
# 3              22.87           Muito baixo                            NaN
# 4              41.31           Médio-baixo                          85.44
#
#    atributo-Pensamento conceitual  atributo-Reflexão  ...  \
# 0                            5.61              10.72  ...
# 1                           21.28              17.23  ...
# 2                           72.18              41.49  ...
# 3                             NaN                NaN  ...
# 4                           90.55              82.03  ...
#
#                 Início - Raciocínio                  Fim - Raciocínio  \
# 0  2019-08-21 16:35:33.827601+00:00  2019-09-02 18:47:40.230133+00:00
# 1  2017-03-11 00:47:44.258948+00:00  2017-03-11 01:36:09.837171+00:00
# 2  2017-04-09 11:48:22.486594+00:00  2017-04-09 12:35:40.925275+00:00
# 3  2016-05-18 21:18:04.261501+00:00  2016-05-18 22:28:54.132025+00:00
# 4  2016-09-12 01:22:45.706329+00:00  2016-09-12 02:24:49.906533+00:00
#
#                    Início - Cultura                     Fim - Cultura  \
# 0  2018-06-12 13:50:12.544201+00:00  2019-09-02 18:45:58.610119+00:00
# 1  2017-03-11 04:39:17.036294+00:00  2017-03-11 04:44:18.962437+00:00
# 2  2017-04-09 12:38:23.387423+00:00  2017-04-09 12:43:47.091106+00:00
# 3  2016-05-18 22:52:06.038503+00:00  2016-05-18 22:57:58.911020+00:00
# 4  2016-09-12 02:25:19.996132+00:00  2016-09-12 02:30:27.135027+00:00
#
#                     Início - Social                      Fim - Social  \
# 0  2019-08-21 16:36:46.205308+00:00  2019-09-02 18:47:52.188799+00:00
# 1  2017-03-11 05:08:18.867391+00:00  2017-03-11 05:22:52.602643+00:00
# 2  2017-04-09 13:05:14.795158+00:00  2017-04-09 13:14:37.327611+00:00
# 3                               NaN                               NaN
# 4  2016-09-27 21:29:39.650033+00:00  2016-10-01 15:21:30.723428+00:00
#
#               Início - Motivacional                Fim - Motivacional  \
# 0  2017-10-02 21:37:08.829909+00:00  2017-10-02 21:37:55.440674+00:00
# 1  2017-03-11 04:55:58.406306+00:00  2017-03-11 05:06:41.817962+00:00
# 2  2017-04-09 12:53:30.554098+00:00  2017-04-09 13:05:01.111152+00:00
# 3                               NaN                               NaN
# 4  2016-09-26 01:52:37.631780+00:00  2016-09-26 02:08:20.131566+00:00
#
#                     Início - Perfil                      Fim - Perfil
# 0  2019-09-02 18:48:52.221133+00:00  2019-09-02 18:49:55.512234+00:00
# 1  2017-03-11 04:46:18.698012+00:00  2017-03-11 04:52:43.434487+00:00
# 2  2017-04-09 12:44:57.652249+00:00  2017-04-09 12:52:19.887744+00:00
# 3                               NaN                               NaN
# 4  2016-09-26 02:10:02.246086+00:00  2016-09-26 02:17:52.166309+00:00
#
# [5 rows x 49 columns]

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4281 entries, 0 to 4280
# Data columns (total 49 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   CPF                                  4281 non-null   object
#  1   Potencial Bruto                      928 non-null    float64
#  2   Raciocínio                           3234 non-null   float64
#  3   Social                               981 non-null    float64
#  4   Motivacional                         956 non-null    float64
#  5   Cultura pontuação                    3311 non-null   float64
#  6   Cultura classificação                3311 non-null   object
#  7   atributo-Capacidade analítica        921 non-null    float64
#  8   atributo-Pensamento conceitual       921 non-null    float64
#  9   atributo-Reflexão                    921 non-null    float64
#  10  atributo-Pensamento criativo         921 non-null    float64
#  11  atributo-Planejamento e organização  921 non-null    float64
#  12  atributo-Comunicação                 921 non-null    float64
#  13  atributo-Consideração pelos outros   921 non-null    float64
#  14  atributo-Influência                  921 non-null    float64
#  15  atributo-Sociabilidade               921 non-null    float64
#  16  atributo-Facilitação                 921 non-null    float64
#  17  atributo-Flexibilidade               921 non-null    float64
#  18  atributo-Estabilidade emocional      921 non-null    float64
#  19  atributo-Ambição                     921 non-null    float64
#  20  atributo-Iniciativa                  921 non-null    float64
#  21  atributo-Assertividade               921 non-null    float64
#  22  atributo-Tomada de riscos            921 non-null    float64
#  23  perfil-Capacidade analítica          1019 non-null   float64
#  24  perfil-Pensamento conceitual         1019 non-null   float64
#  25  perfil-Reflexão                      1019 non-null   float64
#  26  perfil-Pensamento criativo           1019 non-null   float64
#  27  perfil-Planejamento e organização    1019 non-null   float64
#  28  perfil-Comunicação                   1019 non-null   float64
#  29  perfil-Consideração pelos outros     1019 non-null   float64
#  30  perfil-Influência                    1019 non-null   float64
#  31  perfil-Sociabilidade                 1019 non-null   float64
#  32  perfil-Facilitação                   1019 non-null   float64
#  33  perfil-Flexibilidade                 1019 non-null   float64
#  34  perfil-Estabilidade emocional        1019 non-null   float64
#  35  perfil-Ambição                       1019 non-null   float64
#  36  perfil-Iniciativa                    1019 non-null   float64
#  37  perfil-Assertividade                 1019 non-null   float64
#  38  perfil-Tomada de riscos              1019 non-null   float64
#  39  Início - Raciocínio                  3508 non-null   object
#  40  Fim - Raciocínio                     3221 non-null   object
#  41  Início - Cultura                     3337 non-null   object
#  42  Fim - Cultura                        3297 non-null   object
#  43  Início - Social                      998 non-null    object
#  44  Fim - Social                         981 non-null    object
#  45  Início - Motivacional                967 non-null    object
#  46  Fim - Motivacional                   956 non-null    object
#  47  Início - Perfil                      1027 non-null   object
#  48  Fim - Perfil                         1019 non-null   object
# dtypes: float64(37), object(12)
# memory usage: 1.6+ MB

# %% [markdown]
# There are 5 tests:
#
# Raciocínio, Cultura, Social, Motivacional, Perfil

# %% [markdown]
# ## Drop columns not used now

# %%
#Clean url information
url_labels = ["URL Raciocínio","URL Cultura","URL Social","URL Motivacional","URL Perfil"]
df_raw = df_raw.drop(url_labels, axis=1)
#Clean information not useful now
not_useful_labels = ["Nome",'Sobrenome','E-mail','Match']
df_raw = df_raw.drop(not_useful_labels, axis=1)

# %% [markdown]
# As a first approach, I will not use the time took to do the the test as a feature for analysis. Maybe it does not makes sense anyway

# %%
not_useful_for_now_labels = ['Início - Perfil','Fim - Perfil','Início - Motivacional','Fim - Motivacional','Início - Social','Fim - Social',"Início - Raciocínio",'Fim - Raciocínio','Início - Cultura','Fim - Cultura']
df_raw = df_raw.drop(not_useful_for_now_labels, axis=1)

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4281 entries, 0 to 4280
# Data columns (total 39 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   CPF                                  4281 non-null   object
#  1   Potencial Bruto                      928 non-null    float64
#  2   Raciocínio                           3234 non-null   float64
#  3   Social                               981 non-null    float64
#  4   Motivacional                         956 non-null    float64
#  5   Cultura pontuação                    3311 non-null   float64
#  6   Cultura classificação                3311 non-null   object
#  7   atributo-Capacidade analítica        921 non-null    float64
#  8   atributo-Pensamento conceitual       921 non-null    float64
#  9   atributo-Reflexão                    921 non-null    float64
#  10  atributo-Pensamento criativo         921 non-null    float64
#  11  atributo-Planejamento e organização  921 non-null    float64
#  12  atributo-Comunicação                 921 non-null    float64
#  13  atributo-Consideração pelos outros   921 non-null    float64
#  14  atributo-Influência                  921 non-null    float64
#  15  atributo-Sociabilidade               921 non-null    float64
#  16  atributo-Facilitação                 921 non-null    float64
#  17  atributo-Flexibilidade               921 non-null    float64
#  18  atributo-Estabilidade emocional      921 non-null    float64
#  19  atributo-Ambição                     921 non-null    float64
#  20  atributo-Iniciativa                  921 non-null    float64
#  21  atributo-Assertividade               921 non-null    float64
#  22  atributo-Tomada de riscos            921 non-null    float64
#  23  perfil-Capacidade analítica          1019 non-null   float64
#  24  perfil-Pensamento conceitual         1019 non-null   float64
#  25  perfil-Reflexão                      1019 non-null   float64
#  26  perfil-Pensamento criativo           1019 non-null   float64
#  27  perfil-Planejamento e organização    1019 non-null   float64
#  28  perfil-Comunicação                   1019 non-null   float64
#  29  perfil-Consideração pelos outros     1019 non-null   float64
#  30  perfil-Influência                    1019 non-null   float64
#  31  perfil-Sociabilidade                 1019 non-null   float64
#  32  perfil-Facilitação                   1019 non-null   float64
#  33  perfil-Flexibilidade                 1019 non-null   float64
#  34  perfil-Estabilidade emocional        1019 non-null   float64
#  35  perfil-Ambição                       1019 non-null   float64
#  36  perfil-Iniciativa                    1019 non-null   float64
#  37  perfil-Assertividade                 1019 non-null   float64
#  38  perfil-Tomada de riscos              1019 non-null   float64
# dtypes: float64(37), object(2)
# memory usage: 1.3+ MB

# %%
df_raw.describe()
# Out:
#        Potencial Bruto   Raciocínio      Social  Motivacional  \
# count       928.000000  3234.000000  981.000000    956.000000
# mean         50.955830    48.525662   49.994281     53.502720
# std          12.757365    19.744368   18.704857     18.021227
# min          10.220000     6.810000    1.910000      5.550000
# 25%          42.552500    33.582500   37.650000     41.170000
# 50%          51.600000    49.275000   50.820000     51.560000
# 75%          60.080000    63.480000   63.990000     67.140000
# max          84.540000    95.020000   93.860000     95.340000
#
#        Cultura pontuação  atributo-Capacidade analítica  \
# count        3311.000000                     921.000000
# mean           43.100713                      55.206178
# std            16.799244                      23.370183
# min             0.350000                       2.200000
# 25%            30.630000                      37.300000
# 50%            41.700000                      57.120000
# 75%            54.300000                      75.680000
# max           100.000000                     100.000000
#
#        atributo-Pensamento conceitual  atributo-Reflexão  \
# count                      921.000000         921.000000
# mean                        48.860738          43.551759
# std                         22.074096          21.348733
# min                          0.000000           0.000000
# 25%                         32.040000          27.050000
# 50%                         50.400000          43.270000
# 75%                         66.380000          59.460000
# max                         94.830000          95.890000
#
#        atributo-Pensamento criativo  atributo-Planejamento e organização  ...  \
# count                    921.000000                           921.000000  ...
# mean                      47.059685                            53.006634  ...
# std                       21.957383                            20.758994  ...
# min                        0.000000                             6.670000  ...
# 25%                       30.160000                            37.330000  ...
# 50%                       47.270000                            55.310000  ...
# 75%                       63.810000                            69.350000  ...
# max                       98.230000                            95.230000  ...
#
#        perfil-Consideração pelos outros  perfil-Influência  \
# count                       1019.000000        1019.000000
# mean                          48.533317          53.106467
# std                           17.907274          19.688072
# min                            6.140000           6.140000
# 25%                           37.410000          37.410000
# 50%                           46.500000          55.590000
# 75%                           60.140000          69.230000
# max                           91.860000          93.160000
#
#        perfil-Sociabilidade  perfil-Facilitação  perfil-Flexibilidade  \
# count           1019.000000         1019.000000           1019.000000
# mean              55.326644           49.031776             47.591168
# std               21.835068           19.827474             15.513477
# min                6.140000            4.840000              7.440000
# 25%               37.410000           32.860000             37.410000
# 50%               55.590000           51.050000             46.500000
# 75%               73.770000           64.680000             60.140000
# max               93.160000           93.160000             91.860000
#
#        perfil-Estabilidade emocional  perfil-Ambição  perfil-Iniciativa  \
# count                    1019.000000     1019.000000        1019.000000
# mean                       53.654367       50.956418          50.824907
# std                        21.140600       19.701314          16.185858
# min                         6.140000        6.140000           8.740000
# 25%                        37.410000       37.410000          41.950000
# 50%                        55.590000       51.050000          51.050000
# 75%                        69.230000       64.680000          60.140000
# max                        93.160000       93.160000          91.860000
#
#        perfil-Assertividade  perfil-Tomada de riscos
# count           1019.000000              1019.000000
# mean              41.486497                39.824239
# std               15.844941                16.087899
# min                4.840000                 4.840000
# 25%               28.320000                28.320000
# 50%               41.950000                41.950000
# 75%               51.050000                51.050000
# max               91.860000                90.560000
#
# [8 rows x 37 columns]

# %% [markdown]
# All the quantitative metrics are between [0,100] interval

# %%
df_raw["Cultura classificação"].value_counts()
# Out:
# Médio-baixo    734
# Baixo          671
# Médio          636
# Muito baixo    474
# Médio-alto     426
# Alto           245
# Muito alto     125
# Name: Cultura classificação, dtype: int64

# %%
df_raw['atributo-Capacidade analítica']
# Out:
# 0        9.02
# 1       15.53
# 2       81.20
# 3         NaN
# 4       85.44
#         ...
# 4276    64.81
# 4277      NaN
# 4278      NaN
# 4279    44.98
# 4280      NaN
# Name: atributo-Capacidade analítica, Length: 4281, dtype: float64

# %%
df_raw['perfil-Capacidade analítica']
# Out:
# 0       32.86
# 1       28.32
# 2       64.68
# 3         NaN
# 4       64.68
#         ...
# 4276    64.68
# 4277      NaN
# 4278      NaN
# 4279    37.41
# 4280      NaN
# Name: perfil-Capacidade analítica, Length: 4281, dtype: float64

# %%
df_raw.head()
# Out:
#               CPF  Potencial Bruto  Raciocínio  Social  Motivacional  \
# 0  582.975.481-98            15.02       10.89    8.50         30.78
# 1  618.492.035-98            41.18       27.31   31.07         77.53
# 2  376.104.598-11            56.78       71.39   47.53         46.36
# 3  056.378.194-75              NaN       63.01     NaN           NaN
# 4  235.406.789-56            50.96       79.87   21.19         46.36
#
#    Cultura pontuação Cultura classificação  atributo-Capacidade analítica  \
# 0              61.62            Médio-alto                           9.02
# 1              71.92                  Alto                          15.53
# 2              49.10                 Médio                          81.20
# 3              22.87           Muito baixo                            NaN
# 4              41.31           Médio-baixo                          85.44
#
#    atributo-Pensamento conceitual  atributo-Reflexão  ...  \
# 0                            5.61              10.72  ...
# 1                           21.28              17.23  ...
# 2                           72.18              41.49  ...
# 3                             NaN                NaN  ...
# 4                           90.55              82.03  ...
#
#    perfil-Consideração pelos outros  perfil-Influência  perfil-Sociabilidade  \
# 0                             41.95              69.23                 64.68
# 1                             73.77              78.32                 82.86
# 2                             51.05              60.14                 19.23
# 3                               NaN                NaN                   NaN
# 4                             51.05              23.77                 23.77
#
#    perfil-Facilitação  perfil-Flexibilidade  perfil-Estabilidade emocional  \
# 0               55.59                 69.23                          64.68
# 1               46.50                 64.68                          14.68
# 2               23.77                 32.86                          93.16
# 3                 NaN                   NaN                            NaN
# 4               23.77                 28.32                          73.77
#
#    perfil-Ambição  perfil-Iniciativa  perfil-Assertividade  \
# 0           55.59              46.50                 32.86
# 1           51.05              55.59                 60.14
# 2           93.16              28.32                 19.23
# 3             NaN                NaN                   NaN
# 4           64.68              46.50                 37.41
#
#    perfil-Tomada de riscos
# 0                    23.77
# 1                    64.68
# 2                    41.95
# 3                      NaN
# 4                    46.50
#
# [5 rows x 39 columns]

# %% [markdown]
# DO: Understand if information in "Cultura classificação" and "Cultura pontuação" are redundant
# NEED TO UNDESTAND:
#
# - how the "potencial bruto" is calculated. If it is a mean of the other variables it could be redundant.
# - What is the difference between the "atributo" and the "perfil" categories?

# %% [markdown]
# NEED TO KNOW: In performance, what is the best, 1 or 3?

# %% [markdown]
# DO: I will not use the CPF in the model training, however, I need it to connect the area and performance datasets.
#
# After I finished it doing it, I will not need it anymore. However, after the prediction, I should have a way of finding for each CPF, if it is OK in its function or if it could be better to transferr it to other area.

# %% [markdown]
# What will be the prediction? The performance OR/AND the area the person should be?

# %% [markdown]
# Possibilities:

# %% [markdown]
# 1 - Classify what are the best profiles for each area: (X=atributos+performance(com grande peso),y=area)

# %% [markdown]
# 2- Cluster the profiles of JUST the best performances for each area(Xspace =BEST)

# %% [markdown]
# 3 - Create a model that given the person metrics (pysc test), gives as output the probability that the person has to be good in each area.
# This probability will be measured as the distance of this person to the cluster of the best profiles of each area.
